# %%
import pandas as pd
df = pd.read_csv('../DATA/westpactweets.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'location', 'picurl', 'followers', 'dt', 'text',
#        'rts', 'favs', 'urls', 'hashtags', 'cleantext', 'propurl'],
#       dtype='object')

# %%
df[:5]
# Out:
#    Unnamed: 0                name            location  \
# 0           0  Lavenia Rokovucago                Fiji
# 1           1        Westpac Bank           Australia
# 2           2        Lynne Cazaly                 AUS
# 3           3        Lynne Cazaly                 AUS
# 4           4    James W Grenning  Bonita Springs, FL
#
#                                               picurl  followers  \
# 0                                                NaN        312
# 1  https://abs.twimg.com/images/themes/theme7/bg.gif      59103
# 2  https://abs.twimg.com/images/themes/theme16/bg...       8746
# 3  https://abs.twimg.com/images/themes/theme16/bg...       8746
# 4  https://abs.twimg.com/images/themes/theme1/bg.png       5824
#
#                     dt                                               text  \
# 0  2021-05-18 03:37:09  Mission accomplished! Apparently you have to b...
# 1  2021-05-18 03:17:24  @lynnecazaly Thanks Lynne. I look forward to h...
# ...
